# %% [markdown]
# <a href="https://colab.research.google.com/github/yogitamishra1/datascience/blob/main/assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv("SalaryData_Train.csv")

# %%
train
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 18640   62   Self-emp-not-inc        HS-grad            9
# 18641   44            Private   Some-college           10
# 18642   28          Local-gov        HS-grad            9
# 18643   68          Local-gov        Masters           14
# 18644   40        Federal-gov   Some-college           10
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 18640        Never-married       Other-service       Unmarried   White
# 18641             Divorced        Craft-repair   Not-in-family   White
# 18642   Married-civ-spouse     Protective-serv         Husband   White
# 18643              Widowed      Prof-specialty       Unmarried   Black
# 18644        Never-married        Adm-clerical       Unmarried   White
#
#            sex  capitalgain  capitalloss  hoursperweek          native  Salary
# 0         Male         2174            0            40   United-States   <=50K
# 1         Male            0            0            13   United-States   <=50K
# 2         Male            0            0            40   United-States   <=50K
# 3         Male            0            0            40   United-States   <=50K
# 4       Female            0            0            40            Cuba   <=50K
# ...        ...          ...          ...           ...             ...     ...
# 18640   Female            0            0             6   United-States   <=50K
# 18641     Male            0            0            55   United-States   <=50K
# 18642     Male         3908            0            40   United-States   <=50K
# 18643   Female            0            0            40   United-States    >50K
# 18644   Female            0            0            40     United-Stat     NaN
#
# [18645 rows x 14 columns]

# %%
train.shape
# Out:
# (18645, 14)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18645 entries, 0 to 18644
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            18645 non-null  int64
#  1   workclass      18645 non-null  object
#  2   education      18645 non-null  object
#  3   educationno    18645 non-null  int64
#  4   maritalstatus  18645 non-null  object
#  5   occupation     18645 non-null  object
#  6   relationship   18645 non-null  object
#  7   race           18645 non-null  object
#  8   sex            18645 non-null  object
#  9   capitalgain    18645 non-null  int64
#  10  capitalloss    18645 non-null  int64
#  11  hoursperweek   18645 non-null  int64
#  12  native         18645 non-null  object
#  13  Salary         18644 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 2.0+ MB

# %%
test=pd.read_csv("SalaryData_Test.csv")

# %%
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
test.shape
# Out:
# (15060, 14)

# %%
#Combining the both train and test data to perform the naive bayes classifer
data=pd.merge(train,test)

# %%
data
# Out:
#       age   workclass      education  educationno        maritalstatus  \
# 0      38     Private        HS-grad            9             Divorced
# 1      19     Private        HS-grad            9        Never-married
# 2      19     Private        HS-grad            9        Never-married
# 3      19     Private        HS-grad            9        Never-married
# 4      19     Private        HS-grad            9        Never-married
# ...   ...         ...            ...          ...                  ...
# 3631   45     Private      Assoc-voc           11   Married-civ-spouse
# 3632   45     Private      Assoc-voc           11   Married-civ-spouse
# 3633   45     Private      Assoc-voc           11   Married-civ-spouse
# 3634   56   Local-gov        HS-grad            9   Married-civ-spouse
# 3635   24     Private   Some-college           10        Never-married
#
#               occupation    relationship    race      sex  capitalgain  \
# 0      Handlers-cleaners   Not-in-family   White     Male            0
# 1           Craft-repair       Own-child   White     Male            0
# 2           Craft-repair       Own-child   White     Male            0
# 3           Craft-repair       Own-child   White     Male            0
# 4           Craft-repair       Own-child   White     Male            0
# ...                  ...             ...     ...      ...          ...
# 3631        Craft-repair         Husband   White     Male            0
# 3632        Craft-repair         Husband   White     Male            0
# 3633        Craft-repair         Husband   White     Male            0
# 3634        Craft-repair         Husband   White     Male            0
# 3635        Adm-clerical       Own-child   Black   Female            0
#
#       capitalloss  hoursperweek          native  Salary
# 0               0            40   United-States   <=50K
# 1               0            40   United-States   <=50K
# 2               0            40   United-States   <=50K
# 3               0            40   United-States   <=50K
# 4               0            40   United-States   <=50K
# ...           ...           ...             ...     ...
# 3631            0            40   United-States   <=50K
# 3632            0            40   United-States   <=50K
# 3633            0            40   United-States   <=50K
# 3634            0            40   United-States   <=50K
# 3635            0            40   United-States   <=50K
#
# [3636 rows x 14 columns]

# %%
data.shape
# Out:
# (3636, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3636 entries, 0 to 3635
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            3636 non-null   int64
#  1   workclass      3636 non-null   object
#  2   education      3636 non-null   object
#  3   educationno    3636 non-null   int64
#  4   maritalstatus  3636 non-null   object
#  5   occupation     3636 non-null   object
#  6   relationship   3636 non-null   object
#  7   race           3636 non-null   object
#  8   sex            3636 non-null   object
#  9   capitalgain    3636 non-null   int64
#  10  capitalloss    3636 non-null   int64
#  11  hoursperweek   3636 non-null   int64
#  12  native         3636 non-null   object
#  13  Salary         3636 non-null   object
# dtypes: int64(5), object(9)
# memory usage: 426.1+ KB

# %%
data.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
def count_plot(data, columns):
    plt.figure(figsize=(15,10))
    for indx, var in enumerate(columns):
        plt.subplot(5,3,indx+1)
        g=sns.countplot(data[var],hue=data['Salary'])
    plt.tight_layout()
features=data.columns.tolist()
features.remove('Salary')
features
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native']

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
count_plot(data,features)

# %%
for var in features:
    print(data[var].value_counts().sort_values(ascending=False)/data.shape[0])
    print('='*30)
    print()
# Out:
# 20    0.050055
# 21    0.047030
# 32    0.043454
# 23    0.042354
# 36    0.039879
# 33    0.039329
# 29    0.038779
# 19    0.036854
# 24    0.034653
# 37    0.033553
# 26    0.032178
# 31    0.031353
# 25    0.030253
# 22    0.029153
# 35    0.029153
# 41    0.026678
# 39    0.026678
# 38    0.025853
# 28    0.025578
# 34    0.025303
# 43    0.024477
# 27    0.023652
# 30    0.022277
# 18    0.021452
# 17    0.020627
# 40    0.020352
# 44    0.018427
# 51    0.018152
# 42    0.016227
# 50    0.014301
# 46    0.012376
# 47    0.012101
# 45    0.009901
# 53    0.009626
# 49    0.008801
# 56    0.008251
# 48    0.007151
# 55    0.006326
# 52    0.006051
# 54    0.005776
# 57    0.005501
# 58    0.005501
# 59    0.004950
# 61    0.002475
# 62    0.002200
# 63    0.001100
# 64    0.001100
# 60    0.001100
# 65    0.000825
# 66    0.000550
# 67    0.000275
# Name: age, dtype: float64
# ==============================
#
#  Private             0.970572
#  Local-gov           0.011001
#  Self-emp-not-inc    0.005776
#  Self-emp-inc        0.004675
#  State-gov           0.004400
#  Federal-gov         0.003575
# Name: workclass, dtype: float64
# ==============================
#
#  HS-grad         0.569032
#  Some-college    0.208471
#  Bachelors       0.147690
#  11th            0.026953
#  Masters         0.015127
#  Assoc-voc       0.009626
#  10th            0.009351
#  Assoc-acdm      0.003850
#  12th            0.002475
#  9th             0.001925
#  Prof-school     0.001375
#  Doctorate       0.001375
#  7th-8th         0.001100
#  1st-4th         0.000550
#  5th-6th         0.000550
#  Preschool       0.000550
# Name: education, dtype: float64
# ==============================
#
# 9     0.569032
# 10    0.208471
# 13    0.147690
# 7     0.026953
# 14    0.015127
# 11    0.009626
# 6     0.009351
# 12    0.003850
# 8     0.002475
# 5     0.001925
# 15    0.001375
# 16    0.001375
# 4     0.001100
# 2     0.000550
# 3     0.000550
# 1     0.000550
# Name: educationno, dtype: float64
# ==============================
#
#  Married-civ-spouse    0.559406
#  Never-married         0.387514
#  Divorced              0.050880
#  Separated             0.001375
#  Widowed               0.000825
# Name: maritalstatus, dtype: float64
# ==============================
#
#  Craft-repair         0.358911
#  Adm-clerical         0.127063
#  Sales                0.103960
#  Machine-op-inspct    0.101210
#  Exec-managerial      0.077283
#  Other-service        0.071782
#  Prof-specialty       0.062431
#  Handlers-cleaners    0.044279
#  Transport-moving     0.040154
#  Tech-support         0.008251
#  Farming-fishing      0.002750
#  Protective-serv      0.001925
# Name: occupation, dtype: float64
# ==============================
#
#  Husband           0.551430
#  Own-child         0.251925
#  Not-in-family     0.160891
#  Unmarried         0.025028
#  Wife              0.007976
#  Other-relative    0.002750
# Name: relationship, dtype: float64
# ==============================
#
#  White                 0.991474
#  Black                 0.007701
#  Asian-Pac-Islander    0.000825
# Name: race, dtype: float64
# ==============================
#
#  Male      0.773377
#  Female    0.226623
# Name: sex, dtype: float64
# ==============================
#
# 0        0.997250
# 15024    0.000825
# 7298     0.000825
# 7688     0.000550
# 5178     0.000275
# 2407     0.000275
# Name: capitalgain, dtype: float64
# ==============================
#
# 0       0.99890
# 2415    0.00055
# 1902    0.00055
# Name: capitalloss, dtype: float64
# ==============================
#
# 40    0.805831
# 20    0.059956
# 50    0.047580
# 45    0.016777
# 25    0.012651
# 30    0.010726
# 15    0.010726
# 60    0.009901
# 35    0.009076
# 55    0.003025
# 10    0.003025
# 16    0.001925
# 38    0.001375
# 12    0.001100
# 8     0.001100
# 48    0.001100
# 44    0.001100
# 24    0.000825
# 18    0.000550
# 43    0.000275
# 34    0.000275
# 70    0.000275
# 36    0.000275
# 65    0.000275
# 56    0.000275
# Name: hoursperweek, dtype: float64
# ==============================
#
#  United-States    0.996150
#  Mexico           0.003025
#  Philippines      0.000550
#  Jamaica          0.000275
# Name: native, dtype: float64
# ==============================

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve,roc_auc_score,recall_score,precision_score
from sklearn.metrics import f1_score,classification_report
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from statsmodels.stats.outliers_influence import variance_inflation_factor
from collections import Counter

# %%
encoder=OrdinalEncoder()
data_encoded=encoder.fit_transform(data[features])
data_encoded=pd.DataFrame(data_encoded, columns=features)
data_encoded
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0     21.0        2.0       11.0          8.0            0.0         4.0
# 1      2.0        2.0       11.0          8.0            2.0         1.0
# 2      2.0        2.0       11.0          8.0            2.0         1.0
# 3      2.0        2.0       11.0          8.0            2.0         1.0
# 4      2.0        2.0       11.0          8.0            2.0         1.0
# ...    ...        ...        ...          ...            ...         ...
# 3631  28.0        2.0        8.0         10.0            1.0         1.0
# 3632  28.0        2.0        8.0         10.0            1.0         1.0
# 3633  28.0        2.0        8.0         10.0            1.0         1.0
# 3634  39.0        1.0       11.0          8.0            1.0         1.0
# 3635   7.0        2.0       15.0          9.0            2.0         0.0
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0              1.0   2.0  1.0          0.0          0.0          14.0     3.0
# 1              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 2              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 4              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# ...            ...   ...  ...          ...          ...           ...     ...
# 3631           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3632           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3633           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3634           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3635           3.0   1.0  0.0          0.0          0.0          14.0     3.0
#
# [3636 rows x 13 columns]

# %%
encoder1=LabelEncoder()
data_encoded1=encoder1.fit_transform(data['Salary'])
data_encoded1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
data_encoded['Salary']=data_encoded1

# %%
data_encoded
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0     21.0        2.0       11.0          8.0            0.0         4.0
# 1      2.0        2.0       11.0          8.0            2.0         1.0
# 2      2.0        2.0       11.0          8.0            2.0         1.0
# 3      2.0        2.0       11.0          8.0            2.0         1.0
# 4      2.0        2.0       11.0          8.0            2.0         1.0
# ...    ...        ...        ...          ...            ...         ...
# 3631  28.0        2.0        8.0         10.0            1.0         1.0
# 3632  28.0        2.0        8.0         10.0            1.0         1.0
# 3633  28.0        2.0        8.0         10.0            1.0         1.0
# 3634  39.0        1.0       11.0          8.0            1.0         1.0
# 3635   7.0        2.0       15.0          9.0            2.0         0.0
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0              1.0   2.0  1.0          0.0          0.0          14.0     3.0
# 1              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 2              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# 4              3.0   2.0  1.0          0.0          0.0          14.0     3.0
# ...            ...   ...  ...          ...          ...           ...     ...
# 3631           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3632           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3633           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3634           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 3635           3.0   1.0  0.0          0.0          0.0          14.0     3.0
#
#       Salary
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 3631       0
# 3632       0
# 3633       0
# 3634       0
# 3635       0
#
# [3636 rows x 14 columns]

# %%
data_encoded.shape
# Out:
# (3636, 14)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
X=data_encoded.iloc[:,0:-1]
y=data_encoded['Salary']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=10)

# %%
X_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 2523  11.0        2.0       15.0          9.0            1.0         1.0
# 101    8.0        2.0        9.0         12.0            2.0         2.0
# 1853   1.0        2.0        1.0          6.0            2.0         9.0
# 2889  21.0        2.0        9.0         12.0            1.0         2.0
# 333    5.0        2.0       15.0          9.0            2.0         0.0
# ...    ...        ...        ...          ...            ...         ...
# 1965  15.0        2.0       11.0          8.0            1.0         1.0
# 1758  32.0        2.0       11.0          8.0            1.0         2.0
# 2548  17.0        2.0       15.0          9.0            1.0         1.0
# 567   31.0        2.0       11.0          8.0            1.0         5.0
# 2937  25.0        2.0       15.0          9.0            0.0         2.0
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 2523           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 101            1.0   2.0  0.0          0.0          0.0          14.0     3.0
# 1853           3.0   2.0  0.0          0.0          0.0           1.0     3.0
# 2889           0.0   2.0  1.0          0.0          0.0          22.0     3.0
# 333            3.0   2.0  1.0          0.0          0.0          14.0     3.0
# ...            ...   ...  ...          ...          ...           ...     ...
# 1965           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 1758           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 2548           0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 567            0.0   2.0  1.0          0.0          0.0          14.0     3.0
# 2937           4.0   2.0  0.0          0.0          0.0          17.0     3.0
#
# [1091 rows x 13 columns]

# %%
X_test.shape,X_train.shape,y_train.shape,y_test.shape
# Out:
# ((1091, 13), (2545, 13), (2545,), (1091,))

# %%
model=MultinomialNB()
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
count_misclassified=(y_test !=y_pred).sum()
count_misclassified
# Out:
# 270

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.7525206232813932

# %%
print('Accuracy:{:.2f}'.format(accuracy))
# Out:
# Accuracy:0.75

# %%
print("precision:",precision_score(y_test,y_pred,average='micro'))
print("f1 score:",f1_score(y_test,y_pred,average='micro'))
print("recall score:",recall_score(y_test,y_pred,average='micro'))
# Out:
# precision: 0.7525206232813932
# f1 score: 0.7525206232813932
# recall score: 0.7525206232813932

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84       906
#            1       0.37      0.65      0.47       185
#
#     accuracy                           0.75      1091
#    macro avg       0.64      0.71      0.66      1091
# weighted avg       0.82      0.75      0.78      1091

# %%
#Gaussian Naive Bayes Classifier

model1=GaussianNB()
model1.fit(X_train,y_train)
y_pred_gnb=model1.predict(X_test)
y_pred_gnb
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
count_misclassified=(y_test !=y_pred_gnb).sum()
count_misclassified
# Out:
# 427

# %%
#There are more missclassifications in GassianNB when compared to MultinomialNB
print("Recall score : ", recall_score(y_test, y_pred_gnb , average='micro'))
print("Precision score : ",precision_score(y_test, y_pred_gnb , average='micro'))
print("F1 score : ",f1_score(y_test, y_pred_gnb , average='micro'))
# Out:
# Recall score :  0.608615948670944
# Precision score :  0.608615948670944
# F1 score :  0.608615948670944
